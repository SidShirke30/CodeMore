# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
##scatter plot
plt.scatter(df['Weight'],df['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
plt.show()

# %%
##correlation
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
##seaborn for visualisation
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
##divide into independent and dependent feature
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
X=df[['Weight']] ## independent feature must be dataframe or 2D array
X.head()
y=df['Height'] ## this variable can be in series or in 1D array

# %%
np.array(y).shape
# Out:
# (23,)

# %%
## Train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 2
#       1 ## Train test split
# ----> 2 from sklearn.model_selection import train_test_split
#       3 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
##Standardization
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
##Apply Simple linear Regression
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
regression
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("Coefficient or slope:",regression.coef_) ### y^ = B0 + B1*x1 the value we are getting is B1
print("Intercept:",regression.intercept_) ### here we are getting the value of B0
# Out:
# Coefficient or slope: [17.2982057]
# Intercept: 156.47058823529412

# %%
## plot training data plot best fit line
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))
plt.show()

# %%
## prediction for test data
y_pred=regression.predict(X_test)

# %%
## performance metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 114.84069295228699
# 9.665125886795005
# 10.716374991212605

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7360826717981276

# %%
## adjusted r2
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6701033397476595

# %%
## OLS Linear Regression
import statsmodels.api as sm

# %%
model=sm.OLS(y_train,X_train).fit()

# %%
prediction=model.predict(X_test)

# %%
print(prediction)
# Out:
# [  5.79440897   5.79440897 -28.78711691  23.60913442  -7.82861638
#   34.08838469]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Height   R-squared (uncentered):                   0.012
# Model:                            OLS   Adj. R-squared (uncentered):             -0.050
# Method:                 Least Squares   F-statistic:                             0.1953
# Date:                Sun, 28 Dec 2025   Prob (F-statistic):                       0.664
# Time:                        20:42:59   Log-Likelihood:                         -110.03
# No. Observations:                  17   AIC:                                      222.1
# Df Residuals:                      16   BIC:                                      222.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
## prediction for new data
regression.predict(scaler.transform([[72]]))
# Out:
# C:\Users\Santosh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([155.97744705])
